# %% [markdown]
# <a href="https://colab.research.google.com/github/Marcel-12345/244107020141-mobile-course/blob/main/PCVK_W3_244107020141_AnselmusMarcel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT GAMBAR
from google.colab import drive
drive.mount("/content/drive")

# SEL IDENTITAS
import sys, platform, hashlib, datetime, zoneinfo

NAMA = 'Anselmus Marcel Putra Andria'
NIM  = '244107020141'

N     = int(NIM[-3:])
PARAM = {
    'b'    : (N % 61) + 20,
    'a'    : round(1.0 + (N % 9) / 10, 1),
    'c'    : (N % 20) + 30,
    'gamma': round(0.4 + (N % 6) * 0.25, 2),
    'bit'  : (N % 6) + 2,
}
waktu = datetime.datetime.now(zoneinfo.ZoneInfo('Asia/Jakarta'))

print('NAMA   :', NAMA)
print('NIM    :', NIM, '| N =', N)
for k, v in PARAM.items():
    print('%-6s :' % k, v)
print('WAKTU  :', waktu.strftime('%Y-%m-%d %H:%M:%S %Z'))
print('SISTEM :', sys.version.split()[0], platform.platform())
kunci = NIM + '|' + waktu.strftime('%Y-%m-%d')
print('TOKEN  :', hashlib.sha256(kunci.encode()).hexdigest()[:16])

#1 Transformasi Linear Brightness
print("No. 1: Transformasi Linear Brightness");

hasil_wrap = citra + b                                                  # uint8 berputar: 240 + 20 -> 4
hasil_sat  = cv.add(citra, np.full(citra.shape, b, np.uint8))           # saturasi   : 240 + 20 -> 255
hasil_clip = np.clip(citra.astype(np.int16) + b, 0, 255).astype(np.uint8)
# Out:
# Mounted at /content/drive
# NAMA   : Anselmus Marcel Putra Andria
# NIM    : 244107020141 | N = 141
# b      : 39
# a      : 1.6
# c      : 31
# gamma  : 1.15
# bit    : 5
# WAKTU  : 2026-09-15 10:53:55 WIB
# SISTEM : 3.13.15 Linux-6.6.122+-x86_64-with-glibc2.39
# TOKEN  : 2868b3a175703724
# No. 1
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1458/3948503339.py in <cell line: 0>()
#      31 print("No. 1");
#      32
# ---> 33 hasil_wrap = citra + b                                                  # uint8 berputar: 240 + 20 -> 4
#      34 hasil_sat  = cv.add(citra, np.full(citra.shape, b, np.uint8))           # saturasi   : 240 + 20 -> 255
#      35 hasil_clip = np.clip(citra.astype(np.int16) + b, 0, 255).astype(np.uint8)
#
# NameError: name 'citra' is not defined
